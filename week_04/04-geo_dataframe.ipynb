# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#GeoDataframe-/-Carto" data-toc-modified-id="GeoDataframe-/-Carto-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>GeoDataframe / Carto</a></span></li></ul></div>

# %% [markdown]
# ### GeoDataframe / Carto

# %% [markdown]
# ![mapa](../images/geo_portada.jpg)

# %%
import requests
import json
from dotenv import load_dotenv
import os
import pandas as pd

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# Hay APIS para un montón de cosas, aquí os dejo GEOCODE
# - https://geocode.xyz/

# %%
donde = "madrid"

# %%
data = requests.get(f"https://geocode.xyz/{donde}?json=1").json()

# %%
data
# Out:
# {'standard': {'addresst': {},
#   'city': 'Madrid',
#   'prov': 'ES',
#   'countryname': 'Spain',
#   'postal': {},
#   'confidence': '0.90'},
#  'longt': '-3.67930',
#  'alt': {'loc': {'longt': '-3.64539',
#    'prov': 'ES',
#    'city': 'Madrid',
#    'countryname': 'Spain',
#    'postal': '28017',
#    'region': {},
#    'latt': '40.42882'}},
#  'elevation': {},
#  'latt': '40.42955'}

# %%
def geocode(direcciones): 
    """
    Saca las coordenadas de una dirección. que le des.
    """
    data = requests.get(f"https://geocode.xyz/{direcciones}?json=1").json()
    try:
        return {
            "type":"Point",
            "coordinates":  [float(data["latt"]), float(data["longt"])]
        }
    except:
        return data

# %%
madrid = geocode(donde)

# %%
granvia = geocode("calle gran vía, madrid")

# %%
granvia
# Out:
# {'type': 'Point', 'coordinates': [40.41966, -3.69894]}

# %%
# LATITUD LONGITIUD DE MADRID
madrid
# Out:
# {'type': 'Point', 'coordinates': [40.42955, -3.6793]}

# %% [markdown]
# A veces Geocode Falla, así que plan es sacar las coordenadas de la web

# %%
madrid_porsifalla = {'type': 'Point', 'coordinates': [-3.6793, 40.42955]}

# %% [markdown]
# ¿Queremos hacernos una base de datos con todos los restaurantes Veganos de Madrid que hay en Foursquare?
# EEEEAAAASSSSYYYY (¡¡Somos programadoras!!) 🚀🙃🐭🔥🐼🤯

# %% [markdown]
# Lamento deciros que lo primerito es leer la documentación de la API.
# - https://developer.foursquare.com/docs/api-reference/venues/search/

# %% [markdown]
# #QUEYOYAESTABAREGISTRADA así que ya tengo token ....

# %%
#Pero lo he guardado en un .env para que no me llegue ningún e-mail BOMBA 💌💣

# %%
tok1 = os.getenv("tok1")
tok2 = os.getenv("tok2")

# %%
tok2
# Out:
# 'IVNFFZHGH04R1S5QD15PMXFGJRNM2HDBOJSXGICFZYVDEWCW'

# %%
#url = "https://favqs.com/api/session"
url_query = 'https://api.foursquare.com/v2/venues/search?ll=40.7,-74&client_id=CLIENT_ID&client_secret=CLIENT_SECRET&v=YYYYMMDD
'
vegan = "4bf58dd8d48988d1d3941735"

# %%
parametros = {
    
    "client_id": tok1,
    "client_secret": tok2,
    "v": "20180323",
    "ll": f"{madrid.get('coordinates')[0]}, {madrid.get('coordinates')[1]}",
    "query": f"{vegan}",
    "limit": 100 
}

# %%
resp = requests.get(url_query, parametros).json()

# %%
resp
# Out:
# {'meta': {'code': 200, 'requestId': '60d31f48597b674b72d92af5'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'suggestedRadius': 1857,
#   'headerLocation': 'Lista',
#   'headerFullLocation': 'Lista, Madrid',
#   'headerLocationGranularity': 'neighborhood',
#   'query': '4bf58dd8d48988d1d3941735',
#   'totalResults': 19,
#   'suggestedBounds': {'ne': {'lat': 40.47205489596985,
#     'lng': -3.671258145249127},
#    'sw': {'lat': 40.37340656429336, 'lng': -3.718670814180229}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d3b508bcc48224b8ad2454f',
#        'name': 'Vinos De Bellota',
#        'contact': {},
#        'location': {'address': 'Calle de Antonio Acuña, 27',
#         'crossStreet': 'Calle del Doctor Castelo, 3',
#         'lat': 40.42067595716258,
#         'lng': -3.679058690556566,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42067595716258,
#           'lng': -3.679058690556566}],
#         'distance': 988,
#         'postalCode': '28009',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle de Antonio Acuña, 27 (Calle del Doctor Castelo, 3)',
#          '28009 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '70263066'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4d3b508bcc48224b8ad2454f-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ce6f885678aa093a567dfea',
#        'name': 'De María',
#        'contact': {},
#        'location': {'address': 'C. Hortaleza, 81',
#         'lat': 40.42583894572515,
#         'lng': -3.6973308451332096,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42583894572515,
#           'lng': -3.6973308451332096}],
#         'distance': 1582,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Hortaleza, 81',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d107941735',
#          'name': 'Argentinian Restaurant',
#          'pluralName': 'Argentinian Restaurants',
#          'shortName': 'Argentinian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4ce6f885678aa093a567dfea-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b48af5df964a520c95226e3',
#        'name': "D'Mystic",
#        'contact': {},
#        'location': {'address': 'C. Gravina, 7',
#         'lat': 40.42321461360654,
#         'lng': -3.698125448981271,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42321461360654,
#           'lng': -3.698125448981271}],
#         'distance': 1744,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'neighborhood': 'Chueca',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Gravina, 7',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1d8941735',
#          'name': 'Gay Bar',
#          'pluralName': 'Gay Bars',
#          'shortName': 'Gay Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/gaybar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b48af5df964a520c95226e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e159a9262844b405cb1a922',
#        'name': 'SANZ CABREJAS Bufete de Abogados penalista',
#        'contact': {},
#        'location': {'address': 'c/ Serrano, 112 1º Int. Izqda.',
#         'lat': 40.435539978925924,
#         'lng': -3.6863636970520015,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.435539978925924,
#           'lng': -3.6863636970520015}],
#         'distance': 896,
#         'postalCode': '28006',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['c/ Serrano, 112 1º Int. Izqda.',
#          '28006 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b3f',
#          'name': 'Lawyer',
#          'pluralName': 'Lawyers',
#          'shortName': 'Lawyer',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lawschool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '52118239'},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4e159a9262844b405cb1a922-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f7c5159e4b077ebda0dee69',
#        'name': "D'kebab Food",
#        'contact': {},
#        'location': {'address': 'Hortaleza 42',
#         'lat': 40.4222612031427,
#         'lng': -3.699776216224539,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.4222612031427,
#           'lng': -3.699776216224539}],
#         'distance': 1915,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Hortaleza 42', '28004 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d10b941735',
#          'name': 'Falafel Restaurant',
#          'pluralName': 'Falafel Restaurants',
#          'shortName': 'Falafel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4f7c5159e4b077ebda0dee69-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9697def964a5201fd734e3',
#        'name': 'Dia %',
#        'contact': {},
#        'location': {'address': 'C. Cartagena',
#         'lat': 40.44144964184968,
#         'lng': -3.67500296584956,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.44144964184968,
#           'lng': -3.67500296584956}],
#         'distance': 1373,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Cartagena', 'Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b9697def964a5201fd734e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b842fd3f964a5204e2631e3',
#        'name': "D'Mystic",
#        'contact': {},
#        'location': {'address': 'Plaza de Chueca, 9',
#         'lat': 40.4226982042139,
#         'lng': -3.6976243418029884,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.4226982042139,
#           'lng': -3.6976243418029884}],
#         'distance': 1730,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Plaza de Chueca, 9',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b842fd3f964a5204e2631e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ea28fd699117fc56c845361',
#        'name': 'Plaza de España',
#        'contact': {},
#        'location': {'address': 'Pl. de España',
#         'lat': 40.42350614676677,
#         'lng': -3.712016344070434,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42350614676677,
#           'lng': -3.712016344070434}],
#         'distance': 2852,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. de España',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4ea28fd699117fc56c845361-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc4becb4cdfc9b614189921',
#        'name': 'D.O.C.C. Prado',
#        'contact': {},
#        'location': {'address': 'C. Prado, 28',
#         'lat': 40.41542314137755,
#         'lng': -3.697077675115983,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41542314137755,
#           'lng': -3.697077675115983}],
#         'distance': 2177,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Prado, 28', '28014 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4bc4becb4cdfc9b614189921-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4daa1c6dcda1652a2b85e602',
#        'name': "D'Night",
#        'contact': {},
#        'location': {'lat': 40.421503592014204,
#         'lng': -3.6987008608043914,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.421503592014204,
#           'lng': -3.6987008608043914}],
#         'distance': 1872,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d11f941735',
#          'name': 'Nightclub',
#          'pluralName': 'Nightclubs',
#          'shortName': 'Nightclub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4daa1c6dcda1652a2b85e602-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dcbe4b8315135c0aaaf5477',
#        'name': 'Dak-Tak',
#        'contact': {},
#        'location': {'address': 'C. Hilarión Eslava, 51',
#         'lat': 40.43850744850461,
#         'lng': -3.716515692865179,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.43850744850461,
#           'lng': -3.716515692865179}],
#         'distance': 3307,
#         'postalCode': '28015',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Hilarión Eslava, 51',
#          '28015 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1f1941735',
#          'name': 'Board Shop',
#          'pluralName': 'Board Shops',
#          'shortName': 'Board Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/surfspot_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4dcbe4b8315135c0aaaf5477-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbf22e2b083a5930ee3a2e9',
#        'name': 'De María',
#        'contact': {},
#        'location': {'address': 'C. Félix Boix, 5',
#         'lat': 40.463408449110624,
#         'lng': -3.6882601044052623,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.463408449110624,
#           'lng': -3.6882601044052623}],
#         'distance': 3844,
#         'postalCode': '28036',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Félix Boix, 5',
#          '28036 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d107941735',
#          'name': 'Argentinian Restaurant',
#          'pluralName': 'Argentinian Restaurants',
#          'shortName': 'Argentinian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4bbf22e2b083a5930ee3a2e9-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c99d05278fc236ab4d92f97',
#        'name': "Cafetería D'Elba",
#        'contact': {},
#        'location': {'address': 'C. Juan Ramón Jiménez, 11',
#         'lat': 40.45791943109529,
#         'lng': -3.6867717952779993,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.45791943109529,
#           'lng': -3.6867717952779993}],
#         'distance': 3220,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Juan Ramón Jiménez, 11',
#          'Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4c99d05278fc236ab4d92f97-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adcda3cf964a520b03d21e3',
#        'name': 'Cine Capitol 3D',
#        'contact': {},
#        'location': {'address': 'Gran Vía, 41',
#         'lat': 40.42063906535641,
#         'lng': -3.7064681978527543,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42063906535641,
#           'lng': -3.7064681978527543}],
#         'distance': 2506,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Gran Vía, 41', '28013 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d180941735',
#          'name': 'Multiplex',
#          'pluralName': 'Multiplexes',
#          'shortName': 'Cineplex',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'events': {'count': 2, 'summary': '2 movies'},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4adcda3cf964a520b03d21e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b695db0f964a52012a02be3',
#        'name': "D'Fábula",
#        'contact': {},
#        'location': {'address': 'Pl. Conde de Barajas, 3',
#         'lat': 40.41446297264826,
#         'lng': -3.708775939268628,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41446297264826,
#           'lng': -3.708775939268628}],
#         'distance': 3010,
#         'postalCode': '28005',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. Conde de Barajas, 3',
#          '28005 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'shortName': 'Spanish',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4b695db0f964a52012a02be3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f40051fe4b07d5e5740fead',
#        'name': "Pizzeria D'oro",
#        'contact': {},
#        'location': {'address': 'C. Ávila 31',
#         'lat': 40.45266308281798,
#         'lng': -3.699938571907183,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.45266308281798,
#           'lng': -3.699938571907183}],
#         'distance': 3110,
#         'cc': 'ES',
#         'country': 'España',
#         'formattedAddress': ['C. Ávila 31', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4f40051fe4b07d5e5740fead-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c080ac3a1b32d7f3c6595f0',
#        'name': '4D Caffetteria Italiana',
#        'contact': {},
#        'location': {'address': 'C/ de Cuchilleros, 17',
#         'lat': 40.41397173630024,
#         'lng': -3.7080895998456374,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41397173630024,
#           'lng': -3.7080895998456374}],
#         'distance': 2993,
#         'postalCode': '28005',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C/ de Cuchilleros, 17',
#          '28005 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4c080ac3a1b32d7f3c6595f0-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b977c9ef964a520a30535e3',
#        'name': 'Metro Duque de Pastrana',
#        'contact': {},
#        'location': {'address': 'C. Mateo Inurria, 36',
#         'crossStreet': 'Paseo de la Habana',
#         'lat': 40.46757088089364,
#         'lng': -3.6792797721071184,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.46757088089364,
#           'lng': -3.6792797721071184}],
#         'distance': 4232,
#         'postalCode': '28036',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Mateo Inurria, 36 (Paseo de la Habana)',
#          '28036 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1fd931735',
#          'name': 'Metro Station',
#          'pluralName': 'Metro Stations',
#          'shortName': 'Metro',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4b977c9ef964a520a30535e3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4df26ac1fa76abc3d869112b',
#        'name': 'Centro Deportivo Municipal Entrevías',
#        'contact': {},
#        'location': {'address': 'Ronda del Sur 4',
#         'lat': 40.37789057936956,
#         'lng': -3.673413266564177,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.37789057936956,
#           'lng': -3.673413266564177}],
#         'distance': 5772,
#         'postalCode': '28053',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Ronda del Sur 4',
#          '28053 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4df26ac1fa76abc3d869112b-18'}]}]}}

# %%
parametros
# Out:
# {'client_i': '1UO1CCM0MHA3AK15FPNUZ5QNYLZ11P0UATF4TBSCKHHJO15B',
#  'client_secret': 'I0EJ2EE0XSB1UA5MILCRS3A2HVKHRD3XKBYXLPPSPWQCQZAS',
#  'v': '20180323',
#  'll': '40.42955, -3.6793',
#  'query': '4bf58dd8d48988d1d3941735',
#  'limit': 100}

# %%
#El value de la key groups del diccionario anterior está en tipo lista con un solo elemento
#Por eso nos quedamos con el elemento cero 👇🏻

# %%
#vamos a visualizar de forma "amigable"  las keys y los values del diccionario para encontrar los datitos
#Echad un ojo a librería pprint

# %%
#Esto ya es la lista de diccionarios de la que tenemos que extraer el nombre y las coordenadas

# %%
# Mis fuentes --stackoverflow

# %%
#!pip3 install cartoframes

# %% [markdown]
# Al final hacemos un mapita con Cartoframes (quemegusta) y os dejo la DOC para que investiguéis porque no hay tiempo pa todo.
# - https://carto.com/developers/cartoframes/
